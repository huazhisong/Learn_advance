# %%
# %pip show llama-index
# %pip install llama-index
# Out:
# Name: llama-index
# Version: 0.12.9
# Summary: Interface between LLMs and your data
# Home-page: https://llamaindex.ai
# Author: Jerry Liu
# Author-email: jerry@llamaindex.ai
# License: MIT
# Location: /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages
# Requires: llama-index-agent-openai, llama-index-cli, llama-index-core, llama-index-embeddings-openai, llama-index-indices-managed-llama-cloud, llama-index-llms-openai, llama-index-multi-modal-llms-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index-readers-file, llama-index-readers-llama-parse, nltk
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install llama-index-llms-ollama
# %pip install llama-index-embeddings-huggingface
# Out:
# Collecting llama-index-llms-ollama
#   Downloading llama_index_llms_ollama-0.5.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.4 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-llms-ollama) (0.12.10)
# Collecting ollama>=0.4.3 (from llama-index-llms-ollama)
#   Downloading ollama-0.4.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.9.5)
# Requirement already satisfied: dataclasses-json in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2024.3.1)
# Requirement already satisfied: httpx in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.9.1)
# Requirement already satisfied: numpy in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.10.4)
# Requirement already satisfied: requests>=2.31.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.9.4)
# Requirement already satisfied: anyio in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (4.4.0)
# Requirement already satisfied: certifi in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.0.5)
# Requirement already satisfied: idna in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.7)
# Requirement already satisfied: sniffio in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.14.0)
# Requirement already satisfied: click in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (8.1.7)
# Requirement already satisfied: joblib in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2024.5.15)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama)
#   Using cached pydantic_core-2.27.2-cp311-cp311-macosx_10_12_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (3.21.3)
# Requirement already satisfied: packaging>=17.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-ollama) (24.1)
# Downloading llama_index_llms_ollama-0.5.0-py3-none-any.whl (6.7 kB)
# Downloading ollama-0.4.5-py3-none-any.whl (13 kB)
# Using cached pydantic_core-2.27.2-cp311-cp311-macosx_10_12_x86_64.whl (1.9 MB)
# Installing collected packages: pydantic-core, ollama, llama-index-llms-ollama
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
# Successfully installed llama-index-llms-ollama-0.5.0 ollama-0.4.5 pydantic-core-2.27.2
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.4.0-py3-none-any.whl.metadata (767 bytes)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.23.4)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-embeddings-huggingface) (0.12.10)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-embeddings-huggingface) (3.1.1)
# Requirement already satisfied: filelock in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.15.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.1)
# Requirement already satisfied: requests in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.9.5)
# Collecting minijinja>=1.0 (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Downloading minijinja-2.5.0-cp38-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (8.8 kB)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.0.31)
# Requirement already satisfied: dataclasses-json in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: httpx in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: numpy in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.10.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.46.2)
# Requirement already satisfied: torch>=1.11.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.1)
# Requirement already satisfied: scipy in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.12.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.9.4)
# Requirement already satisfied: click in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2024.5.15)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.0.3)
# Requirement already satisfied: sympy in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.12.1)
# Requirement already satisfied: jinja2 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.20.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.21.3)
# Requirement already satisfied: anyio in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.5)
# Requirement already satisfied: sniffio in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/hyjiang/miniforge3/envs/py311/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Downloading llama_index_embeddings_huggingface-0.4.0-py3-none-any.whl (8.6 kB)
# Downloading minijinja-2.5.0-cp38-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: minijinja, llama-index-embeddings-huggingface
# Successfully installed llama-index-embeddings-huggingface-0.4.0 minijinja-2.5.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
